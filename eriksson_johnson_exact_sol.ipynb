# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from matplotlib import cm
from matplotlib.ticker import LinearLocator

# %%
def get_r(eps):
    r1 = (1 + math.sqrt((1 + (4*(eps**2)*(math.pi**2)))))/(2*eps)
    r2 = (1 - math.sqrt((1 + (4*(eps**2)*(math.pi**2)))))/(2*eps)

    return r1, r2

# %%
x = np.linspace(0, 1, 1000)
y = np.linspace(0, 1, 1000)
X, Y = np.meshgrid(x, y)
eps_list = [0.1, 0.01, 0.001]
Z = {}
for i, eps in enumerate(eps_list):
    r1, r2 = get_r(eps)
    Z[i] = np.sin(np.pi*Y)*(np.exp(r1*(X-1)) - np.exp(r2*(X-1)))/(np.exp(-r1) - np.exp(-r2))

# plt.contourf(X, Y, Z, 100, cmap='jet')

# %%
plt.rcParams["text.usetex"] = True
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = ["Computer Modern"]
plt.rcParams['xtick.labelsize'] = 11
plt.rcParams['axes.titlesize'] = 11
plt.rcParams['axes.labelsize'] = 11

plt.rcParams['legend.fontsize'] = 11
plt.rcParams['ytick.labelsize'] = 11
plt.rcParams['xtick.labelsize'] = 11

fig, ax = plt.subplots(1,3,subplot_kw={"projection": "3d"}, figsize=(6,8))
# Plot the surface.
surf_1 = ax[0].plot_surface(X, Y, Z[0], cmap=cm.jet,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax[0].set_zlim(0.0, 1.0)
ax[0].zaxis.set_major_locator(LinearLocator(5))
# A StrMethodFormatter is used automatically
ax[0].zaxis.set_major_formatter('{x:.02f}')
ax[0].zaxis.set_ticks([])
ax[0].xaxis.set_ticks([0,0.5,1])
ax[0].yaxis.set_ticks([0,0.5,1])
ax[0].xaxis.set_ticklabels([0,0.5,1])
ax[0].yaxis.set_ticklabels([0,0.5,1])
ax[0].set_xlabel(r'$x$', labelpad=-7)
ax[0].set_ylabel(r'$y$', labelpad=-7)

ax[0].zaxis.set_ticks([0.0,0.5,1])
ax[0].zaxis.set_ticklabels(['','',''])
ax[0].tick_params(axis='both', which='major', pad=-4.5)
# Add a color bar which maps values to colors.
# fig.colorbar(surf, shrink=0.5, aspect=5)
ax[0].set_title('(a)')

surf_2 = ax[1].plot_surface(X, Y, Z[1], cmap=cm.jet,  
                          linewidth=0, antialiased=False)

# Customize the z axis.
ax[1].set_zlim(0.0, 1.0)
ax[1].zaxis.set_major_locator(LinearLocator(5))
# A StrMethodFormatter is used automatically
# ax[1].zaxis.set_major_formatter('{x:.02f}')
ax[1].zaxis.set_ticks([])
ax[1].xaxis.set_ticks([0,0.5,1])
ax[1].yaxis.set_ticks([0,0.5,1])
ax[1].xaxis.set_ticklabels([0,0.5,1])
ax[1].yaxis.set_ticklabels([0,0.5,1])
ax[1].set_xlabel(r'$x$', labelpad=-7)
ax[1].set_ylabel(r'$y$', labelpad=-7)
ax[1].zaxis.set_ticks([0.0,0.5,1])
ax[1].zaxis.set_ticklabels(['','',''])
ax[1].tick_params(axis='both', which='major', pad=-4.5)
ax[1].set_title('(b)')
surf_3 = ax[2].plot_surface(X, Y, Z[2], cmap=cm.jet,  
                            linewidth=0, antialiased=False)

# Customize the z axis.
ax[2].set_zlim(0.0, 1.0)
ax[2].zaxis.set_major_locator(LinearLocator(5))
# A StrMethodFormatter is used automatically
ax[2].zaxis.set_major_formatter('{x:.02f}')
ax[2].zaxis.set_ticks([])
ax[2].xaxis.set_ticks([0,0.5,1])
ax[2].yaxis.set_ticks([0,0.5,1])
ax[2].xaxis.set_ticklabels([0,0.5,1])
ax[2].yaxis.set_ticklabels([0,0.5,1])
ax[2].set_xlabel(r'$x$', labelpad=-7)
ax[2].set_ylabel(r'$y$', labelpad=-7)
ax[2].zaxis.set_ticks([0.0,0.5,1])
ax[2].zaxis.set_ticklabels(['','',''])
ax[2].tick_params(axis='both', which='major', pad=-4.5)
ax[2].set_title('(c)')

cbar = fig.colorbar(surf_3, ax=ax, shrink=0.1, aspect=10)
cbar.set_ticks([0.02,0.5,1])
cbar.set_ticklabels([0.0,0.5,1])


plt.savefig('ej_exact.png', dpi=300, bbox_inches='tight')
